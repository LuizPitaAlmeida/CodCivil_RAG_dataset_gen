# %%
# !pip install jsonschema genson
# Out:
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (4.19.2)
# Collecting genson
#   Downloading genson-1.3.0-py3-none-any.whl (21 kB)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema) (0.18.1)
# Installing collected packages: genson
# Successfully installed genson-1.3.0

# %%
import json
from genson import SchemaBuilder

# Load your JSON document
with open('/content/codigo_civil.json', 'r') as file:
    json_data = json.load(file)

# Initialize the schema builder
builder = SchemaBuilder()
builder.add_object(json_data)

# Generate the schema
schema = builder.to_schema()

# Print the schema or save it to a file
print(json.dumps(schema, indent=4))

# Save the schema to a file
with open('codigo_civil_json_schema.json', 'w') as file:
    json.dump(schema, file, indent=4)
# Out:
# {
#     "$schema": "http://json-schema.org/schema#",
#     "type": "object",
#     "properties": {
#         "introducao": {
#             "type": "string"
#         },
#         "assinatura": {
#             "type": "string"
#         },
#         "indice": {
#             "type": "string"
#         },
#         "parte geral": {
#             "type": "object",
#             "properties": {
#                 "LIVRO I": {
#                     "type": "object",
#                     "properties": {
#                         "nome": {
#                             "type": "string"
#                         },
#                         "T\u00cdTULO I": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array"
#                                 },
#                                 "CAP\u00cdTULO I": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO II": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO III": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array"
#                                         },
#                                         "Se\u00e7\u00e3o I": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o II": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o III": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         }
#                                     },
#                                     "required": [
#                                         "Se\u00e7\u00e3o I",
#                                         "Se\u00e7\u00e3o II",
#                                         "Se\u00e7\u00e3o III",
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 }
#                             },
#                             "required": [
#                                 "CAP\u00cdTULO I",
#                                 "CAP\u00cdTULO II",
#                                 "CAP\u00cdTULO III",
#                                 "artigos",
#                                 "header"
#                             ]
#                         },
#                         "T\u00cdTULO II": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array"
#                                 },
#                                 "CAP\u00cdTULO I": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO II": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO III": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 }
#                             },
#                             "required": [
#                                 "CAP\u00cdTULO I",
#                                 "CAP\u00cdTULO II",
#                                 "CAP\u00cdTULO III",
#                                 "artigos",
#                                 "header"
#                             ]
#                         },
#                         "T\u00cdTULO III": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array",
#                                     "items": {
#                                         "type": "string"
#                                     }
#                                 }
#                             },
#                             "required": [
#                                 "artigos",
#                                 "header"
#                             ]
#                         }
#                     },
#                     "required": [
#                         "T\u00cdTULO I",
#                         "T\u00cdTULO II",
#                         "T\u00cdTULO III",
#                         "nome"
#                     ]
#                 },
#                 "LIVRO II": {
#                     "type": "object",
#                     "properties": {
#                         "nome": {
#                             "type": "string"
#                         },
#                         "T\u00cdTULO I": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array"
#                                 },
#                                 "CAP\u00cdTULO I": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array"
#                                         },
#                                         "Se\u00e7\u00e3o I": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o II": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o III": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o IV": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o V": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         }
#                                     },
#                                     "required": [
#                                         "Se\u00e7\u00e3o I",
#                                         "Se\u00e7\u00e3o II",
#                                         "Se\u00e7\u00e3o III",
#                                         "Se\u00e7\u00e3o IV",
#                                         "Se\u00e7\u00e3o V",
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO II": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO III": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 }
#                             },
#                             "required": [
#                                 "CAP\u00cdTULO I",
#                                 "CAP\u00cdTULO II",
#                                 "CAP\u00cdTULO III",
#                                 "artigos",
#                                 "header"
#                             ]
#                         }
#                     },
#                     "required": [
#                         "T\u00cdTULO I",
#                         "nome"
#                     ]
#                 },
#                 "LIVRO III": {
#                     "type": "object",
#                     "properties": {
#                         "nome": {
#                             "type": "string"
#                         },
#                         "T\u00cdTULO I": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array"
#                                 },
#                                 "CAP\u00cdTULO I": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO II": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO III": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO IV": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array"
#                                         },
#                                         "Se\u00e7\u00e3o I": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o II": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o III": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o IV": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o V": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o VI": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         }
#                                     },
#                                     "required": [
#                                         "Se\u00e7\u00e3o I",
#                                         "Se\u00e7\u00e3o II",
#                                         "Se\u00e7\u00e3o III",
#                                         "Se\u00e7\u00e3o IV",
#                                         "Se\u00e7\u00e3o V",
#                                         "Se\u00e7\u00e3o VI",
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO V": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 }
#                             },
#                             "required": [
#                                 "CAP\u00cdTULO I",
#                                 "CAP\u00cdTULO II",
#                                 "CAP\u00cdTULO III",
#                                 "CAP\u00cdTULO IV",
#                                 "CAP\u00cdTULO V",
#                                 "artigos",
#                                 "header"
#                             ]
#                         },
#                         "T\u00cdTULO II": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array",
#                                     "items": {
#                                         "type": "string"
#                                     }
#                                 }
#                             },
#                             "required": [
#                                 "artigos",
#                                 "header"
#                             ]
#                         },
#                         "T\u00cdTULO III": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array",
#                                     "items": {
#                                         "type": "string"
#                                     }
#                                 }
#                             },
#                             "required": [
#                                 "artigos",
#                                 "header"
#                             ]
#                         },
#                         "T\u00cdTULO IV": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array"
#                                 },
#                                 "CAP\u00cdTULO I": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array"
#                                         },
#                                         "Se\u00e7\u00e3o I": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o II": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o III": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o IV": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         }
#                                     },
#                                     "required": [
#                                         "Se\u00e7\u00e3o I",
#                                         "Se\u00e7\u00e3o II",
#                                         "Se\u00e7\u00e3o III",
#                                         "Se\u00e7\u00e3o IV",
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO II": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 }
#                             },
#                             "required": [
#                                 "CAP\u00cdTULO I",
#                                 "CAP\u00cdTULO II",
#                                 "artigos",
#                                 "header"
#                             ]
#                         },
#                         "T\u00cdTULO V": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array",
#                                     "items": {
#                                         "type": "string"
#                                     }
#                                 }
#                             },
#                             "required": [
#                                 "artigos",
#                                 "header"
#                             ]
#                         }
#                     },
#                     "required": [
#                         "T\u00cdTULO I",
#                         "T\u00cdTULO II",
#                         "T\u00cdTULO III",
#                         "T\u00cdTULO IV",
#                         "T\u00cdTULO V",
#                         "nome"
#                     ]
#                 }
#             },
#             "required": [
#                 "LIVRO I",
#                 "LIVRO II",
#                 "LIVRO III"
#             ]
#         },
#         "parte especial": {
#             "type": "object",
#             "properties": {
#                 "LIVRO I": {
#                     "type": "object",
#                     "properties": {
#                         "nome": {
#                             "type": "string"
#                         },
#                         "T\u00cdTULO I": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array"
#                                 },
#                                 "CAP\u00cdTULO I": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array"
#                                         },
#                                         "Se\u00e7\u00e3o I": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o II": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         }
#                                     },
#                                     "required": [
#                                         "Se\u00e7\u00e3o I",
#                                         "Se\u00e7\u00e3o II",
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO II": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO III": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO IV": {
# ...
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         },
#                                         "Se\u00e7\u00e3o II": {
#                                             "type": "object",
#                                             "properties": {
#                                                 "header": {
#                                                     "type": "string"
#                                                 },
#                                                 "artigos": {
#                                                     "type": "array",
#                                                     "items": {
#                                                         "type": "string"
#                                                     }
#                                                 }
#                                             },
#                                             "required": [
#                                                 "artigos",
#                                                 "header"
#                                             ]
#                                         }
#                                     },
#                                     "required": [
#                                         "Se\u00e7\u00e3o I",
#                                         "Se\u00e7\u00e3o II",
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO X": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO XI": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO XII": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO XIII": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO XIV": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 }
#                             },
#                             "required": [
#                                 "CAP\u00cdTULO I",
#                                 "CAP\u00cdTULO II",
#                                 "CAP\u00cdTULO III",
#                                 "CAP\u00cdTULO IV",
#                                 "CAP\u00cdTULO IX",
#                                 "CAP\u00cdTULO V",
#                                 "CAP\u00cdTULO VI",
#                                 "CAP\u00cdTULO VII",
#                                 "CAP\u00cdTULO VIII",
#                                 "CAP\u00cdTULO X",
#                                 "CAP\u00cdTULO XI",
#                                 "CAP\u00cdTULO XII",
#                                 "CAP\u00cdTULO XIII",
#                                 "CAP\u00cdTULO XIV",
#                                 "artigos",
#                                 "header"
#                             ]
#                         },
#                         "T\u00cdTULO IV": {
#                             "type": "object",
#                             "properties": {
#                                 "header": {
#                                     "type": "string"
#                                 },
#                                 "artigos": {
#                                     "type": "array"
#                                 },
#                                 "CAP\u00cdTULO I": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO II": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO III": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO IV": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO V": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO VI": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 },
#                                 "CAP\u00cdTULO VII": {
#                                     "type": "object",
#                                     "properties": {
#                                         "header": {
#                                             "type": "string"
#                                         },
#                                         "artigos": {
#                                             "type": "array",
#                                             "items": {
#                                                 "type": "string"
#                                             }
#                                         }
#                                     },
#                                     "required": [
#                                         "artigos",
#                                         "header"
#                                     ]
#                                 }
#                             },
#                             "required": [
#                                 "CAP\u00cdTULO I",
#                                 "CAP\u00cdTULO II",
#                                 "CAP\u00cdTULO III",
#                                 "CAP\u00cdTULO IV",
#                                 "CAP\u00cdTULO V",
#                                 "CAP\u00cdTULO VI",
#                                 "CAP\u00cdTULO VII",
#                                 "artigos",
#                                 "header"
#                             ]
#                         }
#                     },
#                     "required": [
#                         "T\u00cdTULO I",
#                         "T\u00cdTULO II",
#                         "T\u00cdTULO III",
#                         "T\u00cdTULO IV",
#                         "nome"
#                     ]
#                 },
#                 "LIVRO COMPLEMENTAR": {
#                     "type": "object",
#                     "properties": {
#                         "header": {
#                             "type": "string"
#                         },
#                         "artigos": {
#                             "type": "array",
#                             "items": {
#                                 "type": "string"
#                             }
#                         }
#                     },
#                     "required": [
#                         "artigos",
#                         "header"
#                     ]
#                 }
#             },
#             "required": [
#                 "LIVRO COMPLEMENTAR",
#                 "LIVRO I",
#                 "LIVRO II",
#                 "LIVRO III",
#                 "LIVRO IV",
#                 "LIVRO V"
#             ]
#         }
#     },
#     "required": [
#         "assinatura",
#         "indice",
#         "introducao",
#         "parte especial",
#         "parte geral"
#     ]
# }

# %%
len(respostas)
# Out:
# 40
